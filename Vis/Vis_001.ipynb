# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('titanic.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data['Age'].hist()
# Out:
# <Axes: >

# %%
data['Pclass'].hist(bins=2)
# Out:
# <Axes: >

# %%
data['Survived'].hist(bins=2)
# Out:
# <Axes: >

# %%
 sns.set_style('darkgrid')

# %%
data['Survived'].hist(bins=2)
# Out:
# <Axes: >

# %%
data['Survived'].plot(kind='hist', bins=2)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.plot.line(x='Age', y='Pclass', figsize=(10, 8))
# Out:
# <Axes: xlabel='Age'>

# %%
data.sort_values(['Age']).plot.line(x='Age', y='Fare', figsize=(10, 8))
# Out:
# <Axes: xlabel='Age'>

# %%
data.plot.scatter(x='Age', y='Pclass', figsize=(10, 8))
# Out:
# <Axes: xlabel='Age', ylabel='Pclass'>

# %%
data.plot.scatter(x='Age', y='Fare', figsize=(10, 8))
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
data.plot.hexbin(x='Age', y='Fare', gridsize=30, figsize=(10, 8))
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
data.plot.hexbin(x='Age', y='Pclass', gridsize=30, figsize=(10, 8))
# Out:
# <Axes: xlabel='Age', ylabel='Pclass'>

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data['Age'].hist()
# Out:
# <Axes: >

# %%
data['Age'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
data['Fare'] .plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
data.hist(figsize=(10, 12))
# Out:
# array([[<Axes: title={'center': 'PassengerId'}>,
#         <Axes: title={'center': 'Survived'}>,
#         <Axes: title={'center': 'Pclass'}>],
#        [<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'SibSp'}>,
#         <Axes: title={'center': 'Parch'}>],
#        [<Axes: title={'center': 'Fare'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
data.plot.box(figsize=(12, 8))
# Out:
# <Axes: >

# %%
d2 = data.drop(['PassengerId', 'Fare', 'Age'], axis=1).plot.box(figsize=(12, 8))

# %%
data = [1, 2, 3, 7, 9, 10, 11, 12]
plt.boxplot(data)
plt.show()

# %%
data = [1, 2, 3, 7, 9, 10, 11, 12, 13]
series = pd.Series(data)
series.plot.box()
# Out:
# <Axes: >

# %%
data = [1, 2, 3, 7, 9, 10, 11, 12, 13]
series = pd.Series(data)
series.plot.box()
plt.show()

# %%
pd.DataFrame([1, 2, 3, 7, 9, 10, 11, 12, 13]).plot.box()
# Out:
# <Axes: >

# %%
pd.DataFrame([1, 2, 3, 7, 9, 10, 11, 12, 13]).quantile([0.25, 0.5, 0.75])
# Out:
#          0
# 0.25   3.0
# 0.50   9.0
# 0.75  11.0
